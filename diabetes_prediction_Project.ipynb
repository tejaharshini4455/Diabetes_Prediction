# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as p
import seaborn as sns
import warnings

#Ignore warnings
warnings.filterwarnings('ignore')

#Seaborn visualization set up
# %matplotlib inline

# %%
# Importing the dataset
df=pd.read_csv('/content/drive/MyDrive/diabetes.csv')

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]>

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.describe().T  # T is for transpose
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
from matplotlib import pyplot as p
x1=df['Pregnancies']
y1=df['Outcome']
p.plot(x1,y1,'b')  #blue
p.xlabel('Pregnancies')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x1=df['Pregnancies']
y1=df['Outcome']
p.scatter(x1,y1,color='b')
p.xlabel('Pregnancies')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x2=df['Glucose']
y2=df['Outcome']
p.plot(x2,y2,'r')  #red
p.xlabel('Glucose')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x2=df['Glucose']
y2=df['Outcome']
p.scatter(x2,y2,color='r')
p.xlabel('Glucose')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x3=df['BloodPressure']
y3=df['Outcome']
p.plot(x3,y3,'g')  #green
p.xlabel('BloodPressure')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x3=df['BloodPressure']
y3=df['Outcome']
p.scatter(x3,y3,color='g')
p.xlabel('BloodPressure')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x4=df['SkinThickness']
y4=df['Outcome']
p.plot(x4,y4,'y')  #yellow
p.xlabel('SkinThickness')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x4=df['SkinThickness']
y4=df['Outcome']
p.scatter(x4,y4,color='y')
p.xlabel('SkinThickness')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x5=df['Insulin']
y5=df['Outcome']
p.plot(x5,y5,'c')  #cyan
p.xlabel('Insulin')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x5=df['Insulin']
y5=df['Outcome']
p.scatter(x5,y5,color='c')
p.xlabel('Insulin')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x6=df['BMI']
y6=df['Outcome']
p.plot(x6,y6,'m')  #Magenta
p.xlabel('BMI')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x6=df['BMI']
y6=df['Outcome']
p.scatter(x6,y6,color='m')
p.xlabel('BMI')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x7=df['DiabetesPedigreeFunction']
y7=df['Outcome']
p.plot(x7,y7,'k')  #black
p.xlabel('DiabetesPedigreeFunction')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x7=df['DiabetesPedigreeFunction']
y7=df['Outcome']
p.scatter(x7,y7,color='k')
p.xlabel('DiabetesPedigreeFunction')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x8=df['Age']
y8=df['Outcome']
p.plot(x8,y8)
p.xlabel('Age')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
from matplotlib import pyplot as p
x8=df['Age']
y8=df['Outcome']
p.scatter(x8,y8)
p.xlabel('Age')
p.ylabel('Outcome')
# Out:
# Text(0, 0.5, 'Outcome')

# %%
#Checking the distribution of the target variable (Outcome).
#Plotting the distribution of Outcome
sns.countplot(x='Outcome',data=df)

# %%
#Checking the distribution of the predictor variables.
p.figure(1)
p.subplot(121), sns.distplot(df['Glucose'])
p.subplot(122), df['Glucose'].plot.box(figsize=(16,5))
p.show()

# %%
df.isnull().head(10) # To check that if our dataset have null values or not
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0        False    False          False          False    False  False
# 1        False    False          False          False    False  False
# 2        False    False          False          False    False  False
# 3        False    False          False          False    False  False
# 4        False    False          False          False    False  False
# 5        False    False          False          False    False  False
# 6        False    False          False          False    False  False
# 7        False    False          False          False    False  False
# 8        False    False          False          False    False  False
# 9        False    False          False          False    False  False
#
#    DiabetesPedigreeFunction    Age  Outcome
# 0                     False  False    False
# 1                     False  False    False
# 2                     False  False    False
# 3                     False  False    False
# 4                     False  False    False
# 5                     False  False    False
# 6                     False  False    False
# 7                     False  False    False
# 8                     False  False    False
# 9                     False  False    False

# %%
#Checking for any missing values in the dataset.
df.isnull().sum() # To check the number of null values our dataset has.
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df_copy = df.copy(deep = True)
df_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# Showing the Count of NANs
print(df_copy.isnull().sum())
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
sns.pairplot(df,hue='Outcome')

# %%
#Check correlations
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
p.figure(figsize=(12,10))
# seaborn has an easy method to showcase heatmap
p = sns.heatmap(df.corr(), annot=True,cmap ='RdYlGn')

# %%
#Splitting the dataset
#seperate independent and dependent variables
x = df.drop('Outcome', axis=1)
y = df['Outcome']

# %%
#Method 1 to load data in form of array - for easy computation by model
y=df.iloc[:,8:9]
x=df.iloc[:,0:8]

# %%
#Splitting the dataset into Train & Test Dataset

#importing train test split to create vadidation set 
from sklearn.model_selection import train_test_split

#creating the train and validation set
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=7)

# %%
print(x_train)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 590           11      111             84             40        0  46.8
# 692            2      121             70             32       95  39.1
# 492            4       99             68             38        0  32.8
# 205            5      111             72             28        0  23.9
# 709            2       93             64             32      160  38.0
# ..           ...      ...            ...            ...      ...   ...
# 579            2      197             70             99        0  34.7
# 502            6        0             68             41        0  39.0
# 537            0       57             60              0        0  21.7
# 196            1      105             58              0        0  24.3
# 175            8      179             72             42      130  32.7
#
#      DiabetesPedigreeFunction  Age
# 590                     0.925   45
# 692                     0.886   23
# 492                     0.145   33
# 205                     0.407   27
# 709                     0.674   23
# ..                        ...  ...
# 579                     0.575   62
# 502                     0.727   41
# 537                     0.735   67
# 196                     0.187   21
# 175                     0.719   36
#
# [537 rows x 8 columns]

# %%
print(y_train)
# Out:
#      Outcome
# 590        1
# 692        0
# 492        0
# 205        0
# 709        1
# ..       ...
# 579        1
# 502        1
# 537        0
# 196        0
# 175        1
#
# [537 rows x 1 columns]

# %%
#distribution in training set
y_train.value_counts(normalize=True)
# Out:
# Outcome
# 0          0.657356
# 1          0.342644
# dtype: float64

# %%
#distribution in testing set
y_test.value_counts(normalize=True)
# Out:
# Outcome
# 0          0.636364
# 1          0.363636
# dtype: float64

# %%
#shape of training set
x_train.shape, y_train.shape
# Out:
# ((537, 8), (537, 1))

# %%
#shape of testing set
x_test.shape, y_test.shape
# Out:
# ((231, 8), (231, 1))

# %%
#Check columns with zero values

print("Total number of rows: {0}", format (len(df)))
print("Number of rows missing Pregnancies: (0)",format(len(df.loc[df['Pregnancies']==0])))
print("Number of rows missing Glucose: {0}", format(len(df.loc[df['Glucose']==0])))
print("Number of rows missing BloodPressure: {0}", format(len(df.loc[df['BloodPressure']==0])))
print("Number of rows missing SkinThickness: {0}",format (len(df.loc [df[ 'SkinThickness']==0])))
print("Number of rows missing Insulin: (0)",format(len(df.loc[df['Insulin']==0])))
print("Number of rows missing BMI: {0}",format (len (df.loc[df['BMI']==0])))
print("Number of rows missing DiabetesPedigreeFunction: {0}",format(len(df.loc[df['DiabetesPedigreeFunction']==0])))
print("Number of rows assing Age: (03", format(len (df.loc[df['Age']==0])))
# Out:
# Total number of rows: {0} 768
# Number of rows missing Pregnancies: (0) 111
# Number of rows missing Glucose: {0} 5
# Number of rows missing BloodPressure: {0} 35
# Number of rows missing SkinThickness: {0} 227
# Number of rows missing Insulin: (0) 374
# Number of rows missing BMI: {0} 11
# Number of rows missing DiabetesPedigreeFunction: {0} 0
# Number of rows assing Age: (03 0

# %% [markdown]
# # Decision Tree

# %%
#Building the model using DecisionTree

#importimg decision tree classifier
from sklearn.tree import DecisionTreeClassifier

dtree=DecisionTreeClassifier()
DT=dtree.fit(x_train,y_train)

# %%
#Getting the accuracy score for Decision Tree
from sklearn.metrics import accuracy_score
from sklearn import metrics
predictions = DT.predict(x_test)
print("Accuracy Score =", format(metrics.accuracy_score(predictions,y_test)))
# Out:
# Accuracy Score = 0.7142857142857143

# %%
#Classification report and confusion matrix of the decision tree model
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, predictions))
print(classification_report(y_test,predictions))
# Out:
# [[117  30]
#  [ 36  48]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78       147
#            1       0.62      0.57      0.59        84
#
#     accuracy                           0.71       231
#    macro avg       0.69      0.68      0.69       231
# weighted avg       0.71      0.71      0.71       231

# %%
# importing r2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# predicting the accuracy score
score=r2_score(y_test,y_prediction)
print('r2_score is',score)
print('mean_sqrd_error is==',mean_squared_error(y_test,y_prediction))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,y_prediction)))
# Out:
# r2_score is 0.746865306122449
# mean_sqrd_error is== 0.05857662337662338
# root_mean_squared error of is== 0.24202607995136263

# %%
# importing r2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
# predicting the accuracy score
score=r2_score(y_test,y_prediction)
print('r2_socre is',score)
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,y_prediction)))
# Out:
# r2_socre is 0.746865306122449
# root_mean_squared error of is== 0.24202607995136263

# %%
from sklearn import tree
tree.plot_tree(DT,filled=True)
# Out:
# [Text(0.447265625, 0.9642857142857143, 'X[1] <= 127.5\ngini = 0.45\nsamples = 537\nvalue = [353, 184]'),
#  Text(0.20525568181818182, 0.8928571428571429, 'X[7] <= 28.5\ngini = 0.309\nsamples = 346\nvalue = [280, 66]'),
#  Text(0.09517045454545454, 0.8214285714285714, 'X[5] <= 30.95\ngini = 0.155\nsamples = 201\nvalue = [184, 17]'),
#  Text(0.03409090909090909, 0.75, 'X[0] <= 7.5\ngini = 0.036\nsamples = 110\nvalue = [108, 2]'),
#  Text(0.022727272727272728, 0.6785714285714286, 'X[6] <= 0.672\ngini = 0.018\nsamples = 109\nvalue = [108, 1]'),
#  Text(0.011363636363636364, 0.6071428571428571, 'gini = 0.0\nsamples = 95\nvalue = [95, 0]'),
#  Text(0.03409090909090909, 0.6071428571428571, 'X[6] <= 0.713\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.022727272727272728, 0.5357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.045454545454545456, 0.5357142857142857, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.045454545454545456, 0.6785714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15625, 0.75, 'X[6] <= 0.904\ngini = 0.275\nsamples = 91\nvalue = [76, 15]'),
#  Text(0.11931818181818182, 0.6785714285714286, 'X[3] <= 8.0\ngini = 0.24\nsamples = 86\nvalue = [74, 12]'),
#  Text(0.07954545454545454, 0.6071428571428571, 'X[1] <= 110.0\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.06818181818181818, 0.5357142857142857, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.09090909090909091, 0.5357142857142857, 'X[1] <= 123.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.07954545454545454, 0.4642857142857143, 'X[6] <= 0.799\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.06818181818181818, 0.39285714285714285, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.09090909090909091, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10227272727272728, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1590909090909091, 0.6071428571428571, 'X[6] <= 0.501\ngini = 0.176\nsamples = 72\nvalue = [65, 7]'),
#  Text(0.13636363636363635, 0.5357142857142857, 'X[5] <= 31.1\ngini = 0.043\nsamples = 45\nvalue = [44, 1]'),
#  Text(0.125, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14772727272727273, 0.4642857142857143, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(0.18181818181818182, 0.5357142857142857, 'X[2] <= 69.0\ngini = 0.346\nsamples = 27\nvalue = [21, 6]'),
#  Text(0.17045454545454544, 0.4642857142857143, 'X[2] <= 61.0\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.1590909090909091, 0.39285714285714285, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.18181818181818182, 0.39285714285714285, 'X[6] <= 0.544\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.17045454545454544, 0.32142857142857145, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.19318181818181818, 0.32142857142857145, 'X[6] <= 0.652\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.18181818181818182, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.20454545454545456, 0.25, 'X[3] <= 24.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.19318181818181818, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2159090909090909, 0.17857142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19318181818181818, 0.4642857142857143, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.19318181818181818, 0.6785714285714286, 'X[4] <= 63.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.18181818181818182, 0.6071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20454545454545456, 0.6071428571428571, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3153409090909091, 0.8214285714285714, 'X[5] <= 26.35\ngini = 0.447\nsamples = 145\nvalue = [96, 49]'),
#  Text(0.3039772727272727, 0.75, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.32670454545454547, 0.75, 'X[1] <= 99.5\ngini = 0.487\nsamples = 117\nvalue = [68, 49]'),
#  Text(0.23863636363636365, 0.6785714285714286, 'X[1] <= 28.5\ngini = 0.314\nsamples = 41\nvalue = [33, 8]'),
#  Text(0.22727272727272727, 0.6071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.25, 0.6071428571428571, 'X[0] <= 11.5\ngini = 0.26\nsamples = 39\nvalue = [33, 6]'),
#  Text(0.22727272727272727, 0.5357142857142857, 'X[6] <= 1.16\ngini = 0.198\nsamples = 36\nvalue = [32, 4]'),
#  Text(0.2159090909090909, 0.4642857142857143, 'X[1] <= 94.5\ngini = 0.157\nsamples = 35\nvalue = [32, 3]'),
#  Text(0.20454545454545456, 0.39285714285714285, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.22727272727272727, 0.39285714285714285, 'X[1] <= 95.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.2159090909090909, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.23863636363636365, 0.32142857142857145, 'X[7] <= 51.0\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.22727272727272727, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23863636363636365, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2727272727272727, 0.5357142857142857, 'X[2] <= 61.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.26136363636363635, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2840909090909091, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4147727272727273, 0.6785714285714286, 'X[2] <= 85.0\ngini = 0.497\nsamples = 76\nvalue = [35, 41]'),
#  Text(0.375, 0.6071428571428571, 'X[6] <= 0.252\ngini = 0.467\nsamples = 62\nvalue = [23, 39]'),
#  Text(0.32954545454545453, 0.5357142857142857, 'X[1] <= 113.5\ngini = 0.455\nsamples = 20\nvalue = [13, 7]'),
#  Text(0.3068181818181818, 0.4642857142857143, 'X[2] <= 80.0\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.29545454545454547, 0.39285714285714285, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.3181818181818182, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3522727272727273, 0.4642857142857143, 'X[7] <= 32.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.3409090909090909, 0.39285714285714285, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.36363636363636365, 0.39285714285714285, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.42045454545454547, 0.5357142857142857, 'X[1] <= 119.5\ngini = 0.363\nsamples = 42\nvalue = [10, 32]'),
#  Text(0.3977272727272727, 0.4642857142857143, 'X[6] <= 1.395\ngini = 0.225\nsamples = 31\nvalue = [4, 27]'),
#  Text(0.38636363636363635, 0.39285714285714285, 'X[7] <= 58.0\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.36363636363636365, 0.32142857142857145, 'X[0] <= 8.5\ngini = 0.133\nsamples = 28\nvalue = [2, 26]'),
#  Text(0.3522727272727273, 0.25, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.375, 0.25, 'X[2] <= 59.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.36363636363636365, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.38636363636363635, 0.17857142857142858, 'X[5] <= 30.6\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.375, 0.10714285714285714, 'X[4] <= 52.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.36363636363636365, 0.03571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38636363636363635, 0.03571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3977272727272727, 0.10714285714285714, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.4090909090909091, 0.32142857142857145, 'X[0] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3977272727272727, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.42045454545454547, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4090909090909091, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4431818181818182, 0.4642857142857143, 'X[5] <= 29.15\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.4318181818181818, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.45454545454545453, 0.39285714285714285, 'X[6] <= 0.792\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.4431818181818182, 0.32142857142857145, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4659090909090909, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.45454545454545453, 0.6071428571428571, 'X[5] <= 43.05\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.4431818181818182, 0.5357142857142857, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.4659090909090909, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6892755681818182, 0.8928571428571429, 'X[5] <= 28.15\ngini = 0.472\nsamples = 191\nvalue = [73, 118]'),
#  Text(0.5284090909090909, 0.8214285714285714, 'X[1] <= 145.5\ngini = 0.334\nsamples = 33\nvalue = [26, 7]'),
#  Text(0.5, 0.75, 'X[2] <= 73.0\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.48863636363636365, 0.6785714285714286, 'X[2] <= 71.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.4772727272727273, 0.6071428571428571, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5113636363636364, 0.6785714285714286, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.5568181818181818, 0.75, 'X[3] <= 16.5\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.5340909090909091, 0.6785714285714286, 'X[2] <= 25.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.5227272727272727, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5454545454545454, 0.6071428571428571, 'X[0] <= 8.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.5340909090909091, 0.5357142857142857, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.5568181818181818, 0.5357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5795454545454546, 0.6785714285714286, 'X[7] <= 25.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5681818181818182, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5909090909090909, 0.6071428571428571, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8501420454545454, 0.8214285714285714, 'X[1] <= 165.5\ngini = 0.418\nsamples = 158\nvalue = [47, 111]'),
#  Text(0.7457386363636364, 0.75, 'X[6] <= 0.436\ngini = 0.475\nsamples = 111\nvalue = [43, 68]'),
#  Text(0.65625, 0.6785714285714286, 'X[7] <= 24.5\ngini = 0.5\nsamples = 64\nvalue = [32, 32]'),
#  Text(0.6136363636363636, 0.6071428571428571, 'X[2] <= 68.0\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.6022727272727273, 0.5357142857142857, 'X[1] <= 144.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5909090909090909, 0.4642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6136363636363636, 0.4642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.625, 0.5357142857142857, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.6988636363636364, 0.6071428571428571, 'X[5] <= 48.1\ngini = 0.487\nsamples = 50\nvalue = [21, 29]'),
#  Text(0.6875, 0.5357142857142857, 'X[7] <= 41.5\ngini = 0.499\nsamples = 44\nvalue = [21, 23]'),
#  Text(0.6363636363636364, 0.4642857142857143, 'X[7] <= 25.5\ngini = 0.473\nsamples = 26\nvalue = [16, 10]'),
#  Text(0.625, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6477272727272727, 0.39285714285714285, 'X[2] <= 69.0\ngini = 0.423\nsamples = 23\nvalue = [16, 7]'),
#  Text(0.625, 0.32142857142857145, 'X[6] <= 0.279\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.6136363636363636, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6363636363636364, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6704545454545454, 0.32142857142857145, 'X[6] <= 0.285\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.6590909090909091, 0.25, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.6818181818181818, 0.25, 'X[2] <= 77.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6704545454545454, 0.17857142857142858, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6931818181818182, 0.17857142857142858, 'X[4] <= 39.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6818181818181818, 0.10714285714285714, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7045454545454546, 0.10714285714285714, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7386363636363636, 0.4642857142857143, 'X[0] <= 5.5\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.7272727272727273, 0.39285714285714285, 'X[2] <= 92.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.7159090909090909, 0.32142857142857145, 'X[3] <= 16.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.7045454545454546, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7272727272727273, 0.25, 'X[5] <= 32.65\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7159090909090909, 0.17857142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7386363636363636, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7386363636363636, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.75, 0.39285714285714285, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.7102272727272727, 0.5357142857142857, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8352272727272727, 0.6785714285714286, 'X[5] <= 28.85\ngini = 0.359\nsamples = 47\nvalue = [11, 36]'),
#  Text(0.8238636363636364, 0.6071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8465909090909091, 0.6071428571428571, 'X[5] <= 38.6\ngini = 0.32\nsamples = 45\nvalue = [9, 36]'),
#  Text(0.8181818181818182, 0.5357142857142857, 'X[1] <= 164.5\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.8068181818181818, 0.4642857142857143, 'X[7] <= 28.5\ngini = 0.128\nsamples = 29\nvalue = [2, 27]'),
#  Text(0.7954545454545454, 0.39285714285714285, 'X[0] <= 5.0\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.7840909090909091, 0.32142857142857145, 'X[1] <= 131.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.7727272727272727, 0.25, 'X[4] <= 197.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7613636363636364, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7840909090909091, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7954545454545454, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8068181818181818, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8181818181818182, 0.39285714285714285, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.8295454545454546, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.875, 0.5357142857142857, 'X[3] <= 40.5\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.8522727272727273, 0.4642857142857143, 'X[2] <= 80.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.8409090909090909, 0.39285714285714285, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8636363636363636, 0.39285714285714285, 'X[6] <= 0.67\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8522727272727273, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.875, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8977272727272727, 0.4642857142857143, 'X[3] <= 44.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.8863636363636364, 0.39285714285714285, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9090909090909091, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9545454545454546, 0.75, 'X[2] <= 92.0\ngini = 0.156\nsamples = 47\nvalue = [4, 43]'),
#  Text(0.9318181818181818, 0.6785714285714286, 'X[6] <= 0.307\ngini = 0.091\nsamples = 42\nvalue = [2, 40]'),
#  Text(0.9204545454545454, 0.6071428571428571, 'X[6] <= 0.264\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.9090909090909091, 0.5357142857142857, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.9318181818181818, 0.5357142857142857, 'X[5] <= 38.65\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9204545454545454, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9431818181818182, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9431818181818182, 0.6071428571428571, 'gini = 0.0\nsamples = 31\nvalue = [0, 31]'),
#  Text(0.9772727272727273, 0.6785714285714286, 'X[2] <= 99.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.9659090909090909, 0.6071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9886363636363636, 0.6071428571428571, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
#creating the decision tree function
dt_model = DecisionTreeClassifier(random_state=10)

# %%
#fitting the model
dt_model.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(random_state=10)

# %%
#checking the training score
dt_model.score(x_train, y_train)
# Out:
# 1.0

# %%
#checking the testing score
dt_model.score(x_test, y_test)
# Out:
# 0.7186147186147186

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (0.10.1)

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.7/dist-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from pydotplus) (3.0.8)

# %%
#DT = tree.export_graphviz(DT,out_file='tree.dot',feature_names=x_train.columns,max_depth=30,filled=True)

# %%
decision_tree = tree.export_graphviz(dt_model,out_file='tree.dot',feature_names=x_train.columns,max_depth=10,filled=True)

# %%
# !dot -Tpng tree.dot -o tree.png

# %%
image =plt.imread('tree.png')
plt.figure(figsize=(30,30))
plt.imshow(image)

# %% [markdown]
# #Random Forest

# %%
#Building the model using RandomForest
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=200,random_state=10)
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=10)

# %%
y_prediction =  dt.predict(x_test.values)
y_prediction
# Out:
# array([0.  , 0.96, 0.44, 0.16, 0.6 , 0.56, 0.  , 0.52, 0.68, 0.08, 1.  ,
#        0.2 , 0.24, 1.  , 0.32, 0.12, 0.  , 0.2 , 0.28, 0.04, 0.36, 0.  ,
#        0.84, 0.92, 0.04, 0.08, 0.08, 0.2 , 0.76, 0.08, 0.24, 0.  , 0.16,
#        0.72, 0.  , 0.16, 0.84, 0.  , 0.64, 0.88, 0.92, 0.92, 0.2 , 0.  ,
#        0.2 , 0.08, 0.88, 0.4 , 0.92, 0.88, 0.04, 0.  , 0.32, 0.08, 0.92,
#        0.56, 0.2 , 0.  , 0.16, 0.84, 0.12, 0.92, 0.04, 0.92, 0.88, 0.92,
#        0.08, 0.64, 0.92, 0.8 , 0.68, 0.92, 0.08, 0.  , 0.04, 0.04, 0.28,
#        0.08, 0.  , 0.04, 0.04, 0.2 , 0.24, 0.04, 0.12, 0.68, 0.96, 0.72,
#        0.44, 0.  , 0.88, 0.16, 0.92, 0.16, 0.4 , 0.88, 0.8 , 0.  , 0.6 ,
#        0.16, 0.88, 0.32, 0.08, 0.  , 0.  , 0.28, 0.08, 0.4 , 0.08, 0.8 ,
#        0.04, 0.88, 0.88, 0.08, 0.96, 0.16, 0.  , 0.  , 0.8 , 0.76, 0.12,
#        0.  , 0.24, 0.  , 0.  , 0.96, 0.04, 0.44, 0.04, 0.04, 0.  , 0.84,
#        0.  , 0.04, 0.72, 0.  , 0.72, 0.92, 0.  , 0.28, 0.  , 0.64, 0.8 ,
#        0.68, 0.  , 0.  , 0.28, 0.16, 0.76, 0.16, 0.04, 0.72, 0.64, 0.  ,
#        0.08, 0.8 , 0.96, 0.56, 0.92, 0.32, 0.52, 0.04, 0.  , 0.  , 0.96,
#        0.44, 0.12, 0.12, 0.16, 0.96, 0.16, 0.88, 0.84, 0.12, 0.8 , 0.44,
#        0.76, 0.84, 0.84, 0.2 , 0.28, 0.  , 0.  , 0.08, 0.08, 0.32, 0.04,
#        0.  , 0.12, 0.28, 0.2 , 0.2 , 0.8 , 0.96, 0.16, 0.32, 0.6 , 0.  ,
#        0.  , 0.76, 0.2 , 0.76, 0.28, 0.4 , 0.8 , 0.08, 0.2 , 0.  , 0.08,
#        0.  , 1.  , 0.84, 0.08, 0.2 , 0.76, 0.  , 0.2 , 0.92, 0.  , 0.52,
#        0.04, 0.16, 0.56, 0.2 , 0.96, 0.6 , 0.84, 0.12, 0.96, 0.  , 0.12])

# %%
#Getting the accuracy score for Random Forest
from sklearn.metrics import accuracy_score

predictions = rfc.predict(x_test)
print("Accuracy_Score =", format(accuracy_score(y_test, predictions)))
# Out:
# Accuracy_Score = 0.7705627705627706

# %%
#Getting the accuracy score for Random Forest
from sklearn.metrics import mean_squared_error

predictions = rfc.predict(x_test)
print("Accuracy_Score =", format(metrics.mean_squared_error(y_test, predictions)))
# Out:
# Accuracy_Score = 0.22943722943722944

# %%
#Classification report and confusion matrix of random forest model
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, predictions))
print(classification_report(y_test,predictions))
# Out:
# [[124  23]
#  [ 30  54]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82       147
#            1       0.70      0.64      0.67        84
#
#     accuracy                           0.77       231
#    macro avg       0.75      0.74      0.75       231
# weighted avg       0.77      0.77      0.77       231

# %%
# importing r2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
# predicting the accuracy score
score=r2_score(y_test,y_prediction)
print('r2_socre is',score)
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,y_prediction)))
# Out:
# r2_socre is 0.746865306122449
# root_mean_squared error of is== 0.24202607995136263
